# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
atlit = pd.read_csv('Athletes.csv')
gender = pd.read_csv('EntriesGender.csv')
pelatih = pd.read_csv('Coaches.csv')
medali = pd.read_csv('Medals.csv')
tim = pd.read_csv('Teams.csv')

# %%
print("-"*10,"atlit info","-"*10)
atlit.info()
print()
print("-"*10,"gender info","-"*10)
gender.info()
print()
print("-"*10,"pelatih info","-"*10)
pelatih.info()
print()
print("-"*10,"medali info","-"*10)
medali.info()
print()
print("-"*10,"tim info","-"*10)
tim.info()
# Out:
# ---------- atlit info ----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11085 entries, 0 to 11084
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        11085 non-null  object
#  1   NOC         11085 non-null  object
#  2   Discipline  11085 non-null  object
# dtypes: object(3)
# memory usage: 259.9+ KB
#
# ---------- gender info ----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Discipline  46 non-null     object
#  1   Female      46 non-null     int64
#  2   Male        46 non-null     int64
#  3   Total       46 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.6+ KB
#
# ---------- pelatih info ----------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 4 columns):
# ...

# %%
cabor = gender['Discipline'].unique()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
sns.set_style('whitegrid')

# %%
gender[['Male','Female','Discipline']].set_index('Discipline').plot(kind="bar",stacked=True)
figure = plt.gcf()
figure.set_size_inches(15,15)
plt.savefig('C:\\Users\\Mario\\Downloads\\tokyo olympic csv\\graph\\cabor_gender.png',dpi=300)

# %%
medali
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# ..   ...                         ...   ...     ...     ...    ...
# 88    86                       Ghana     0       0       1      1
# 89    86                     Grenada     0       0       1      1
# 90    86                      Kuwait     0       0       1      1
# 91    86         Republic of Moldova     0       0       1      1
# 92    86        Syrian Arab Republic     0       0       1      1
#
#     Rank by Total
# 0               1
# 1               2
# 2               5
# 3               4
# 4               3
# ..            ...
# 88             77
# ...

# %%
medali[['Gold','Silver','Bronze','Team/NOC']].set_index('Team/NOC').plot(kind="bar",stacked=True)
figure = plt.gcf()
figure.set_size_inches(15,15)
plt.savefig('C:\\Users\\Mario\\Downloads\\tokyo olympic csv\\graph\\medali_Gold.png',dpi=300)

# %%
pelatih.loc[pelatih['NOC'] == 'United States of America']
# Out:
#                     Name                       NOC         Discipline  \
# 15     ANDONOVSKI Vlatko  United States of America           Football
# 31            BERG Laura  United States of America  Baseball/Softball
# 41           BROWN Chris  United States of America       Rugby Sevens
# 83         DOBSON Howard  United States of America  Baseball/Softball
# 95        ENGELLAND Chip  United States of America         Basketball
# 96         ENQUIST Susan  United States of America         Volleyball
# 97           ERIKSEN Ken  United States of America  Baseball/Softball
# 109       FLOWERS Tairia  United States of America  Baseball/Softball
# 112          FRIDAY Mike  United States of America       Rugby Sevens
# 113       FUENTES Andrea  United States of America  Artistic Swimming
# 114  FUERBRINGER Matthew  United States of America         Volleyball
# 154        HARDY William  United States of America         Basketball
# ...

# %%
tim.loc[tim['NOC'] == 'United States of America']
# Out:
#                   Name           Discipline                       NOC  \
# 15       United States       3x3 Basketball  United States of America
# 65       United States              Archery  United States of America
# 66       United States              Archery  United States of America
# 67       United States              Archery  United States of America
# 91       United States  Artistic Gymnastics  United States of America
# 92       United States  Artistic Gymnastics  United States of America
# 124      United States    Artistic Swimming  United States of America
# 199      United States            Athletics  United States of America
# 200      United States            Athletics  United States of America
# 201      United States            Athletics  United States of America
# 202      United States            Athletics  United States of America
# 203      United States            Athletics  United States of America
# ...

# %% [markdown]
# # Opini Pribadi

# %% [markdown]
# di karenakan dataset yang kebanyakan memiliki data dengan tipe string ngebuat gua kesulitan memploting data, sehingga gua cuma dapat melalukan ploting pada data-data yang mengandung angka, gua juga kesulitan nyari celah biar gua bisa konek-in antar data; contohnya kayak misalkan data tim sama data medali, gara-gara data di medali gaada cabornya jadi gua pribadi susah buat nyari tau nama tim yang kira kira dapet suatu medali gold/silver/bronze.
